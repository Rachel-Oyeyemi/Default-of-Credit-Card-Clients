# %% [markdown]
# # 02 – Preprocessing
#
# This notebook demonstrates basic preprocessing steps.

# %%
from src.preprocess import load_dataset, preprocess, save_dataset

# Load raw file (converted to CSV)
raw_path = '../data/raw/default_of_credit_card_clients.csv'  # adjust path if needed
processed_path = '../data/processed/credit_default_processed.csv'

# Example usage
# df_raw = load_dataset(raw_path)
# df_clean = preprocess(df_raw)
# save_dataset(df_clean, processed_path)
