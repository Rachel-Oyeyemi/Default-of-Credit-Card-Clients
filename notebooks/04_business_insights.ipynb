# %% [markdown]
# # 04 – Business Insights
#
# Summarise modelling results and derive business recommendations.

# %% [markdown]
# After evaluating multiple models, the Random Forest achieved the best performance.
#
# Key drivers of default include payment status history and payment ratios.  Business recommendations are detailed in the **BUSINESS_RECOMMENDATIONS.md** file.
